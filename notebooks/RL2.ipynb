# %%
# run once per notebook
import sys, pathlib, importlib
ROOT = pathlib.Path.cwd().parents[0]      # …/RL-Pairs-Trading-Replication
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))
print("ROOT on path →", ROOT)
# Out:
# ROOT on path → /Users/freddieliang/Desktop/RL-Pairs-Trading-Replication

# %%
# === Cell: Load and Split Data ===
import pandas as pd

# Load the data, using 'timestamp' column as index and parsing dates
try:
    spread_df = pd.read_csv("../data/test_spread.csv", index_col='timestamp', parse_dates=True)
    spread = spread_df['spread'] # Get the spread Series
    print(f"Loaded spread data with {len(spread)} rows.")
    print(f"Index type: {type(spread.index)}")

    # Split into 80% train and 20% test (using .iloc preserves the index)
    train_size = int(len(spread) * 0.8)
    spread_train = spread.iloc[:train_size]
    spread_test = spread.iloc[train_size:]

    print(f"Train size: {len(spread_train)}, Test size: {len(spread_test)}")
    print(f"Test data index type: {type(spread_test.index)}")
    print(f"First 5 test index values: {spread_test.index[:5]}")

except FileNotFoundError:
    print("Error: ../data/test_spread.csv not found. Make sure make_spread.py ran correctly.")
except Exception as e:
    print(f"Error loading data: {e}")
# Out:
# Loaded spread data with 131101 rows.
# Index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# Train size: 104880, Test size: 26221
# Test data index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# First 5 test index values: DatetimeIndex(['2023-12-13 03:00:00+00:00', '2023-12-13 03:01:00+00:00',
#                '2023-12-13 03:02:00+00:00', '2023-12-13 03:03:00+00:00',
#                '2023-12-13 03:04:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='timestamp', freq=None)

# %%
# Ensure the spread is split correctly
import pandas as pd
spread = pd.read_csv("../data/test_spread.csv")["spread"]
train_size = int(len(spread) * 0.8)
spread_train = spread.iloc[:train_size].reset_index(drop=True)
test_spread = spread.iloc[train_size:].reset_index(drop=True)

from stable_baselines3 import A2C, PPO
from src.rl_environment import PairTradingEnv # Make sure this is imported

RL_VARIANT = "RL2"  # or use "RL2" if you have continuous actions
env_train = PairTradingEnv(
    spread=spread_train.reset_index(drop=True),
    rl_mode=RL_VARIANT,
    window=900,
    open_thr=1.8,
    close_thr=0.4,
    fee=0.0002,
)
ALG = A2C if RL_VARIANT == "RL1" else PPO
model = ALG("MlpPolicy", env_train, verbose=1, tensorboard_log="logs/")
print(f"Training {RL_VARIANT} model...")
model.learn(total_timesteps=100_000) # Or your desired timesteps
model_path = f"models/pair_trading_{RL_VARIANT.lower()}" # Save to a 'models' subfolder
model.save(model_path)
print(f"Model saved to {model_path}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training RL2 model...
# Logging to logs/PPO_4
# /opt/anaconda3/envs/rlpairs/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 4205 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2513         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038819108 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 6.85e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41e+04     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00574     |
# |    std                  | 0.995        |
# |    value_loss           | 3.68e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2353        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003107502 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.000868   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 1           |
# |    value_loss           | 2.54e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2328         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0072070253 |
# |    clip_fraction        | 0.072        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.000983     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+04     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0067      |
# |    std                  | 0.999        |
# |    value_loss           | 3.25e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2334        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.003461574 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.0124     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00323    |
# |    std                  | 0.999       |
# |    value_loss           | 2.37e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2340         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0030626678 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00403     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+04      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00417     |
# |    std                  | 0.994        |
# |    value_loss           | 3.65e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2342         |
# |    iterations           | 7            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0031508885 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.000873    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.56e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.989        |
# |    value_loss           | 1.69e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2345         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0037054133 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.59e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.35e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00521     |
# |    std                  | 0.982        |
# |    value_loss           | 7.22e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2350         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0023296643 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.000493    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.17e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00286     |
# |    std                  | 0.968        |
# |    value_loss           | 1.4e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2355         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0017592773 |
# |    clip_fraction        | 0.0064       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00157     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+04      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 2.66e-05     |
# |    std                  | 0.948        |
# |    value_loss           | 2.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2357        |
# |    iterations           | 11          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.003655092 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00359    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00586    |
# |    std                  | 0.939       |
# |    value_loss           | 3.46e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2359         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0037228093 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000283    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.71e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0045      |
# |    std                  | 0.937        |
# |    value_loss           | 2.97e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2353         |
# |    iterations           | 13           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0015818186 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 4.98e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000808    |
# |    std                  | 0.935        |
# |    value_loss           | 2.8e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2315         |
# |    iterations           | 14           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0023439429 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000169    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.64e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000998    |
# |    std                  | 0.939        |
# |    value_loss           | 7.63e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2269         |
# |    iterations           | 15           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0047390405 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00328     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.8e+04      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000834    |
# |    std                  | 0.937        |
# |    value_loss           | 1.47e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2231         |
# |    iterations           | 16           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0013199043 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.000214    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000919    |
# |    std                  | 0.921        |
# |    value_loss           | 3.32e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2216          |
# |    iterations           | 17            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00025745213 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.000322     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000166     |
# |    std                  | 0.925         |
# |    value_loss           | 2.72e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2196         |
# |    iterations           | 18           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 6.383972e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -3.54e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.66e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 5.78e-05     |
# |    std                  | 0.923        |
# |    value_loss           | 1.53e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2186         |
# |    iterations           | 19           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0030948124 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -1.12e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+05     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.923        |
# |    value_loss           | 2.1e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2164         |
# |    iterations           | 20           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031960167 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -9.87e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.22e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00054      |
# |    std                  | 0.916        |
# |    value_loss           | 7.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2159         |
# |    iterations           | 21           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0013692428 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -2.04e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+05     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000722    |
# |    std                  | 0.914        |
# |    value_loss           | 4.29e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2163        |
# |    iterations           | 22          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021563273 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -2.74e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00234     |
# |    std                  | 0.909       |
# |    value_loss           | 5.61e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2160         |
# |    iterations           | 23           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0047973776 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -1.45e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000381     |
# |    std                  | 0.895        |
# |    value_loss           | 2.73e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2149        |
# |    iterations           | 24          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003746223 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -1.97e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.1e+04     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00132    |
# |    std                  | 0.888       |
# |    value_loss           | 1.08e+05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2141          |
# |    iterations           | 25            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00014759856 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | 1.42e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.63e+05      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | 0.000252      |
# |    std                  | 0.891         |
# |    value_loss           | 3.05e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2124        |
# |    iterations           | 26          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006558057 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.00746    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.99e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000205   |
# |    std                  | 0.898       |
# |    value_loss           | 1.15e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2120        |
# |    iterations           | 27          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007557067 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 5.42e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000639   |
# |    std                  | 0.884       |
# |    value_loss           | 4.56e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2067         |
# |    iterations           | 28           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0006391515 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 4.29e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.1e+05      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000563    |
# |    std                  | 0.884        |
# |    value_loss           | 3.04e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2070          |
# |    iterations           | 29            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 2.8149516e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | -1.91e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.37e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -8.13e-05     |
# |    std                  | 0.883         |
# |    value_loss           | 8.37e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2073         |
# |    iterations           | 30           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0046311356 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -8.34e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.81e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00413     |
# |    std                  | 0.882        |
# |    value_loss           | 9.93e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2077         |
# |    iterations           | 31           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0016883833 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.64e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00354      |
# |    std                  | 0.882        |
# |    value_loss           | 9.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2076         |
# |    iterations           | 32           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0041803843 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -5.48e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00314     |
# |    std                  | 0.876        |
# |    value_loss           | 1.85e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2081          |
# |    iterations           | 33            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 6.4622465e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 7.15e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.06e+05      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000462     |
# |    std                  | 0.877         |
# |    value_loss           | 1.58e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2086         |
# |    iterations           | 34           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 6.103248e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -7.15e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.28e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 6.57e-05     |
# |    std                  | 0.877        |
# |    value_loss           | 5.26e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2088         |
# |    iterations           | 35           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0025101537 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.14e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000365    |
# |    std                  | 0.873        |
# |    value_loss           | 1.23e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2093         |
# |    iterations           | 36           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0025483717 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.0021       |
# |    std                  | 0.88         |
# |    value_loss           | 4.41e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2098        |
# |    iterations           | 37          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.038551617 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -3.93e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.68e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00239     |
# |    std                  | 0.89        |
# |    value_loss           | 1.31e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2102         |
# |    iterations           | 38           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0004318878 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000704     |
# |    std                  | 0.89         |
# |    value_loss           | 3.77e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2105         |
# |    iterations           | 39           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0010725772 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.81e+04     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000346    |
# |    std                  | 0.89         |
# |    value_loss           | 1.21e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2110         |
# |    iterations           | 40           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0015300168 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.98e+04     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00057      |
# |    std                  | 0.891        |
# |    value_loss           | 2.14e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2113        |
# |    iterations           | 41          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.048090085 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.71e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00429     |
# |    std                  | 0.886       |
# |    value_loss           | 1.19e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2114         |
# |    iterations           | 42           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0051928135 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.91e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00174     |
# |    std                  | 0.88         |
# |    value_loss           | 2.23e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2114         |
# |    iterations           | 43           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 1.406236e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.29e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000114    |
# |    std                  | 0.88         |
# |    value_loss           | 2.46e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2114          |
# |    iterations           | 44            |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00094750646 |
# |    clip_fraction        | 0.000732      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.43e+04      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -7.33e-05     |
# |    std                  | 0.878         |
# |    value_loss           | 1.1e+05       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2116          |
# |    iterations           | 45            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00012336017 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.75e+05      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000266     |
# |    std                  | 0.876         |
# |    value_loss           | 3.88e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2116          |
# |    iterations           | 46            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00015337364 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16e+05      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000324     |
# |    std                  | 0.876         |
# |    value_loss           | 2.6e+05       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2120         |
# |    iterations           | 47           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0020654602 |
# |    clip_fraction        | 0.0916       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.0044       |
# |    std                  | 0.877        |
# |    value_loss           | 5.79e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2123          |
# |    iterations           | 48            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00016104436 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.4e+05       |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000223     |
# |    std                  | 0.877         |
# |    value_loss           | 7.54e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2128          |
# |    iterations           | 49            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00049119734 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.26e+05      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000749     |
# |    std                  | 0.877         |
# |    value_loss           | 4.28e+05      |
# -------------------------------------------
# Model saved to models/pair_trading_rl2

# %%
# === Cell: Train Model ===
from stable_baselines3 import A2C, PPO
from src.rl_environment import PairTradingEnv # Make sure this is imported

# Use spread_train from the previous cell
# Reset index *only* for the environment if it requires it
env_train = PairTradingEnv(
    spread=spread_train.reset_index(drop=True), # Reset index for Env if needed
    rl_mode=RL_VARIANT, # Ensure RL_VARIANT is defined ('RL1' or 'RL2')
    # ... other env params ...
)

ALG = A2C if RL_VARIANT == "RL1" else PPO
model = ALG("MlpPolicy", env_train, verbose=1, tensorboard_log="logs/")
print(f"Training {RL_VARIANT} model...")
model.learn(total_timesteps=100_000) # Or your desired timesteps
model_path = f"models/pair_trading_{RL_VARIANT.lower()}" # Save to a 'models' subfolder
model.save(model_path)
print(f"Model saved to {model_path}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training RL2 model...
# Logging to logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 5371 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2509       |
# |    iterations           | 2          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00454335 |
# |    clip_fraction        | 0.0424     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | -1.55e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.76e+04   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00614   |
# |    std                  | 1          |
# |    value_loss           | 3.3e+04    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2429        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002476503 |
# |    clip_fraction        | 0.00806     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -3.58e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00238    |
# |    std                  | 0.99        |
# |    value_loss           | 2.33e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2355         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0065222187 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0101       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+04     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00671     |
# |    std                  | 0.976        |
# |    value_loss           | 2.53e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2292         |
# |    iterations           | 5            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0026840959 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0219       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.15e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.975        |
# |    value_loss           | 2.79e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2213        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007123987 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.68e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00681    |
# |    std                  | 0.965       |
# |    value_loss           | 5.36e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2218        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004038476 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00144    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000799   |
# |    std                  | 0.964       |
# |    value_loss           | 2.15e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2227         |
# |    iterations           | 8            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0011213287 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00112     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.84e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000254    |
# |    std                  | 0.959        |
# |    value_loss           | 9.91e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2232        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002679083 |
# |    clip_fraction        | 0.00547     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000212   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.85e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000236   |
# |    std                  | 0.957       |
# |    value_loss           | 1.06e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2242         |
# |    iterations           | 10           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0031591696 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000125    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 0.953        |
# |    value_loss           | 3.37e+04     |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2251      |
# |    iterations           | 11        |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0034812 |
# |    clip_fraction        | 0.00659   |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.37     |
# |    explained_variance   | -0.00268  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.83e+04  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.000938 |
# |    std                  | 0.95      |
# |    value_loss           | 3.47e+04  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2255         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0009552428 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000224    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00145     |
# |    std                  | 0.952        |
# |    value_loss           | 3.1e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2231         |
# |    iterations           | 13           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0028187945 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 3.89e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00248     |
# |    std                  | 0.951        |
# |    value_loss           | 3.18e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2235         |
# |    iterations           | 14           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0020968197 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000591    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.000117     |
# |    std                  | 0.94         |
# |    value_loss           | 9.07e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2237         |
# |    iterations           | 15           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0053426116 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000647    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+05     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000375     |
# |    std                  | 0.934        |
# |    value_loss           | 3.15e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2217         |
# |    iterations           | 16           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0074594817 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -1.05e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.31e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 0.00102      |
# |    std                  | 0.947        |
# |    value_loss           | 7.15e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2216         |
# |    iterations           | 17           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0041036075 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 5.36e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00206     |
# |    std                  | 0.948        |
# |    value_loss           | 4.04e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2205          |
# |    iterations           | 18            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00046876422 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -1.1e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16e+05      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000821     |
# |    std                  | 0.95          |
# |    value_loss           | 2.63e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2213         |
# |    iterations           | 19           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0010003233 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -2.86e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+05     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000935    |
# |    std                  | 0.951        |
# |    value_loss           | 3.41e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2210         |
# |    iterations           | 20           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0017292978 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -1.96e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.35e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 2.26e-07     |
# |    std                  | 0.947        |
# |    value_loss           | 1.14e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2213          |
# |    iterations           | 21            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00019929264 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -3.93e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.18e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000365     |
# |    std                  | 0.947         |
# |    value_loss           | 6.87e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2219         |
# |    iterations           | 22           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0034714737 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.06e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.95         |
# |    value_loss           | 6.19e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2222         |
# |    iterations           | 23           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0017862475 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -8.58e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 0.943        |
# |    value_loss           | 4.94e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2228         |
# |    iterations           | 24           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0023105294 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000218    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.51e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000196    |
# |    std                  | 0.944        |
# |    value_loss           | 1.77e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2220         |
# |    iterations           | 25           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0026655546 |
# |    clip_fraction        | 0.00815      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 9.24e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.67e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 0.946        |
# |    value_loss           | 4.87e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2221        |
# |    iterations           | 26          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004771027 |
# |    clip_fraction        | 0.0152      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00873    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000813   |
# |    std                  | 0.946       |
# |    value_loss           | 1.71e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2225         |
# |    iterations           | 27           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0005983019 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 3.16e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.07e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 1.25e-05     |
# |    std                  | 0.943        |
# |    value_loss           | 1.2e+05      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2229          |
# |    iterations           | 28            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00019989032 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 3.04e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.03e+05      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000107     |
# |    std                  | 0.943         |
# |    value_loss           | 4.74e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2233          |
# |    iterations           | 29            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00017961985 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -7.99e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.95e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00028      |
# |    std                  | 0.943         |
# |    value_loss           | 1.88e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2236         |
# |    iterations           | 30           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0052769342 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -2.74e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.39e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000817    |
# |    std                  | 0.937        |
# |    value_loss           | 3.06e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2227         |
# |    iterations           | 31           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0059500807 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.42e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000576    |
# |    std                  | 0.948        |
# |    value_loss           | 1.57e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2216         |
# |    iterations           | 32           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0033906302 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -3.7e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55e+05     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.00679      |
# |    std                  | 0.951        |
# |    value_loss           | 2.68e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2213         |
# |    iterations           | 33           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0016004347 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03e+05     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.951        |
# |    value_loss           | 2.91e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2207        |
# |    iterations           | 34          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009606105 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.97e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.000976    |
# |    std                  | 0.949       |
# |    value_loss           | 7.59e+05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2205          |
# |    iterations           | 35            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00029980802 |
# |    clip_fraction        | 0.0272        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.92e+05      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.000572      |
# |    std                  | 0.941         |
# |    value_loss           | 3.06e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2209         |
# |    iterations           | 36           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0019348335 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.71e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00271      |
# |    std                  | 0.944        |
# |    value_loss           | 1.47e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2213        |
# |    iterations           | 37          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015614996 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00242     |
# |    std                  | 0.951       |
# |    value_loss           | 2.65e+05    |
# -----------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2215           |
# |    iterations           | 38             |
# |    time_elapsed         | 35             |
# |    total_timesteps      | 77824          |
# | train/                  |                |
# |    approx_kl            | 0.000117067975 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.37          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2e+05          |
# |    n_updates            | 370            |
# |    policy_gradient_loss | 0.000732       |
# |    std                  | 0.95           |
# |    value_loss           | 3.11e+05       |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2219        |
# |    iterations           | 39          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002571729 |
# |    clip_fraction        | 0.00259     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.35e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000284   |
# |    std                  | 0.951       |
# |    value_loss           | 1.15e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2223        |
# |    iterations           | 40          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003010347 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00133     |
# |    std                  | 0.955       |
# |    value_loss           | 1.75e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2226         |
# |    iterations           | 41           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0018507758 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.86e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.0127       |
# |    std                  | 0.95         |
# |    value_loss           | 1.42e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2229        |
# |    iterations           | 42          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007437789 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00129     |
# |    std                  | 0.946       |
# |    value_loss           | 3.36e+04    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2232          |
# |    iterations           | 43            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00043083596 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.39e+05      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000381     |
# |    std                  | 0.947         |
# |    value_loss           | 3.59e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2235          |
# |    iterations           | 44            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00019049412 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.86e+05      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000371     |
# |    std                  | 0.946         |
# |    value_loss           | 2.88e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2238         |
# |    iterations           | 45           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0046768216 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.12e+05     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00545     |
# |    std                  | 0.947        |
# |    value_loss           | 8.92e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2240         |
# |    iterations           | 46           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0014278311 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000695    |
# |    std                  | 0.947        |
# |    value_loss           | 4.92e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2243         |
# |    iterations           | 47           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0013944348 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.44e+05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000103    |
# |    std                  | 0.948        |
# |    value_loss           | 9.06e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2243          |
# |    iterations           | 48            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00032884564 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6e+05         |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000642     |
# |    std                  | 0.947         |
# |    value_loss           | 1.44e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2245          |
# |    iterations           | 49            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00081547385 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.55e+05      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000316     |
# |    std                  | 0.949         |
# |    value_loss           | 1.13e+06      |
# -------------------------------------------
# Model saved to models/pair_trading_rl2

# %%
import matplotlib.pyplot as plt
import numpy as np # Make sure numpy is imported

# Run simulation to record cumulative P&L (equity curve) on the test set
env_test_curve = PairTradingEnv(test_spread, rl_mode=RL_VARIANT)
obs = env_test_curve.reset()

initial_portfolio_value = 1000000 # Or whatever your assumed starting capital is
portfolio_value = [initial_portfolio_value]
rewards_log = [] # Optional: log rewards to debug

while True:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env_test_curve.step(action)
    rewards_log.append(reward) # Optional debugging

    # Calculate the new portfolio value by adding the absolute reward
    # NOTE: This assumes 'reward' IS the absolute P&L for the step.
    # If not, you might need to scale it or use info dict if it provides P&L.
    current_value = portfolio_value[-1] + reward
    portfolio_value.append(current_value)

    if done:
        break

# Now portfolio_value contains the actual equity curve (unnormalized)
# Normalize it by dividing by the starting value
equity_rl2_normalized = np.array(portfolio_value) / initial_portfolio_value

# Plot the NORMALIZED curve
plt.plot(equity_rl2_normalized)
plt.title("Normalized Equity Curve (Test set)")
plt.xlabel("Step")
plt.ylabel("Equity (Starting at 1)")
plt.show()

# %%
# === New Cell for Cumulative Returns Plot ===
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import PercentFormatter # Import PercentFormatter

# --- Ensure equity_rl_normalized and spread_test are available from previous cells ---
# Assuming 'equity_rl_normalized' (from cell 106) and
# 'spread_test' (the Series/DataFrame with the DatetimeIndex from cell 94/96)
# are loaded and available in the notebook's environment.

print("--- Running Cumulative Returns Plot Cell (Using Existing Variables) ---")

try:
    # --- 1. Align Data (using logic from your drawdown code) ---
    # Create a pandas Series for the normalized equity curve, starting from the second point (value after step 1)
    # Align it with the corresponding dates from the test set index
    # Ensure correct slicing to match lengths
    num_equity_points = len(equity_rl2_normalized)
    if num_equity_points -1 > len(spread_test.index):
        print(f"Warning: Equity curve length ({num_equity_points}) seems too long for test index ({len(spread_test.index)}). Trimming equity curve.")
        equity_curve_values = equity_rl2_normalized[1:len(spread_test.index)+1]
        aligned_dates = spread_test.index
    elif num_equity_points - 1 < len(spread_test.index):
         print(f"Warning: Equity curve length ({num_equity_points}) seems too short for test index ({len(spread_test.index)}). Trimming test index.")
         equity_curve_values = equity_rl2_normalized[1:]
         aligned_dates = spread_test.index[:num_equity_points-1]
    else:
        equity_curve_values = equity_rl2_normalized[1:]
        aligned_dates = spread_test.index

    # Check if alignment resulted in data to plot
    if len(equity_curve_values) == 0:
         print("Error: No data points remain after alignment.")
    else:
        equity_curve_dated = pd.Series(equity_curve_values, index=aligned_dates)
        print(f"Aligned equity curve and dates. Plotting {len(equity_curve_dated)} points.")

        # --- 2. Calculate Cumulative Returns ---
        # Since equity_curve_dated is normalized equity starting from 1, subtract 1 for cumulative return
        cumulative_returns = equity_curve_dated - 1

        # --- 3. Plot Cumulative Returns ---
        plt.figure(figsize=(12, 6))
        plt.plot(cumulative_returns.index, cumulative_returns, label='Cumulative Return', color='blue') # Changed color
        # Removed fill_between as it's more suitable for drawdown

        plt.title('RL2 Strategy Cumulative Returns (Test Set)') # Updated title
        plt.xlabel('Date')
        plt.ylabel('Cumulative Return') # Updated label

        # Format Y-axis as percentage
        plt.gca().yaxis.set_major_formatter(PercentFormatter(xmax=1.0))

        plt.grid(True, alpha=0.5)
        plt.legend()
        plt.show()

except NameError as e:
    print(f"Error: A required variable (e.g., 'equity_rl_normalized' or 'spread_test') is not defined.")
    print("Please ensure the cells that define these variables have been run.")
    print(f"(Specific error: {e})")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

print("--- Finished Cumulative Returns Plot Cell ---")
# Out:
# --- Running Cumulative Returns Plot Cell (Using Existing Variables) ---
# Warning: Equity curve length (26221) seems too short for test index (26221). Trimming test index.
# Aligned equity curve and dates. Plotting 26220 points.
# --- Finished Cumulative Returns Plot Cell ---

# %%
# filepath: /Users/freddieliang/Desktop/RL-Pairs-Trading-Replication/notebooks/RL2.ipynb
# --- New Cell for Drawdown Plot ---
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Ensure equity_rl2_normalized and spread_test are available from previous cells

# Calculate Drawdown
# Use the equity curve starting from the second point to align with dates
equity_curve_for_drawdown = pd.Series(equity_rl2_normalized[1:], index=spread_test.index[:len(equity_rl2_normalized)-1])
running_max = equity_curve_for_drawdown.cummax()
drawdown = (equity_curve_for_drawdown / running_max) - 1

# Plot Drawdown
plt.figure(figsize=(12, 6))
plt.plot(drawdown.index, drawdown, label='Drawdown', color='red')
plt.fill_between(drawdown.index, drawdown, 0, color='red', alpha=0.3)
plt.title('RL2 Strategy Drawdown (Test Set)')
plt.xlabel('Date')
plt.ylabel('Drawdown')
from matplotlib.ticker import PercentFormatter
plt.gca().yaxis.set_major_formatter(PercentFormatter(xmax=1.0))
plt.grid(True, alpha=0.5)
plt.legend()
plt.show()

# %%
# === New Cell: Daily Returns Plot (Styled) ===
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
# NOTE: Removed PercentFormatter as the example doesn't use it

# --- Ensure equity_rl_normalized and spread_test are available ---
# Assuming 'equity_rl_normalized' and 'spread_test' (with DatetimeIndex)
# are available from previous cells.

print("--- Running Styled Daily Returns Plot Cell ---")

try:
    # --- 1. Align Data ---
    num_equity_points = len(equity_rl2_normalized)
    if num_equity_points - 1 > len(spread_test.index):
        equity_curve_values = equity_rl2_normalized[1:len(spread_test.index)+1]
        aligned_dates = spread_test.index
    elif num_equity_points - 1 < len(spread_test.index):
         equity_curve_values = equity_rl2_normalized[1:]
         aligned_dates = spread_test.index[:num_equity_points-1]
    else:
        equity_curve_values = equity_rl2_normalized[1:]
        aligned_dates = spread_test.index

    if len(equity_curve_values) == 0:
         print("Error: No data points remain after alignment.")
    else:
        equity_curve_dated = pd.Series(equity_curve_values, index=aligned_dates)
        print(f"Aligned equity curve and dates. Processing {len(equity_curve_dated)} points.")

        # --- 2. Calculate Daily Returns ---
        equity_daily = equity_curve_dated.resample('D').last()
        daily_returns = equity_daily.pct_change().dropna() # Still need daily % change

        print(f"Calculated {len(daily_returns)} daily return points.")

        # --- 3. Plot Daily Returns (Styled) ---
        if len(daily_returns) > 0:
            # Apply a style similar to the example (adjust 'ggplot' if needed)
            # 'seaborn-v0_8-whitegrid' is another option for white grid
            # plt.style.use('ggplot') # ggplot style often has grey background + white grid

            fig, ax = plt.subplots(figsize=(12, 6))

            # Define colors
            positive_color = 'gold' # Yellow/gold like the example
            negative_color = 'mediumpurple' # Purple/red for negative (adjust as needed)

            # Create masks for positive and negative returns
            positive_mask = daily_returns >= 0
            negative_mask = daily_returns < 0

            # Plot vertical lines using vlines
            ax.vlines(daily_returns.index[positive_mask], 0, daily_returns[positive_mask],
                      color=positive_color, linewidth=2, label='Positive Return')
            ax.vlines(daily_returns.index[negative_mask], 0, daily_returns[negative_mask],
                      color=negative_color, linewidth=2, label='Negative Return')

            # Add horizontal line at zero
            ax.axhline(0, color='grey', linestyle='--', linewidth=0.8)

            ax.set_title('RL2 Strategy Daily Returns (Test Set)')
            ax.set_xlabel('Date')
            ax.set_ylabel('Daily Return') # Label without percentage

            # Grid lines (vertical only like example)
            ax.xaxis.grid(True, linestyle='-', alpha=0.5) # Vertical grid lines
            ax.yaxis.grid(False) # Turn off horizontal grid lines

            # Format X-axis dates
            ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Format like example
            ax.xaxis.set_major_locator(plt.MaxNLocator(8)) # Adjust number of date ticks shown
            plt.xticks(rotation=30, ha='right') # Rotate dates like example

            # Optional: Set background color if style doesn't handle it
            # ax.set_facecolor('#f0f0f0') # Light grey background

            # Optional: Customize spines if needed
            # ax.spines['top'].set_visible(False)
            # ax.spines['right'].set_visible(False)

            # Create a combined legend (optional, as colors are distinct)
            # handles, labels = ax.get_legend_handles_labels()
            # ax.legend(handles, labels) # May show duplicate labels, handle if needed

            plt.tight_layout()
            plt.show()

            # Reset style to default if you don't want it affecting subsequent plots
            # plt.style.use('default')

        else:
            print("No daily returns calculated.")

except NameError as e:
    print(f"Error: A required variable (e.g., 'equity_rl_normalized' or 'spread_test') is not defined.")
    print(f"(Specific error: {e})")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

print("--- Finished Styled Daily Returns Plot Cell ---")
# Out:
# --- Running Styled Daily Returns Plot Cell ---
# Aligned equity curve and dates. Processing 26220 points.
# Calculated 18 daily return points.
# --- Finished Styled Daily Returns Plot Cell ---

# %%
import numpy as np

# Use the normalized equity curve calculated in the previous cell
returns = np.diff(equity_rl2_normalized)                    # 1-step P&L change based on normalized equity
# Adjust Sharpe calculation if needed based on normalized returns
# Assuming returns are now fractional changes (e.g., 0.01 for 1%)
# The Sharpe calculation might need adjustment depending on the exact nature of 'returns'
# If returns = np.diff(equity_rl_normalized) represents the change in the normalized value (e.g., 1.01 - 1.00 = 0.01),
# then the Sharpe ratio calculation might be okay as is, but verify the interpretation.
sharpe  = returns.mean() / returns.std() * np.sqrt(60)  # 60 bars ≈ 1h (Adjust sqrt factor if data frequency differs)

print(f"Mean step P&L (Normalized Change): {returns.mean():.4f}") # Adjusted label
print(f"Sharpe (per-hour proxy): {sharpe:.2f}")

# Calculate drawdown based on the normalized equity curve
max_drawdown_normalized = np.min(equity_rl2_normalized / np.maximum.accumulate(equity_rl2_normalized) - 1)
print(f"Max drawdown (Normalized): {max_drawdown_normalized:.2%}") # Display as percentage

# ...rest of the notebook...
# Out:
# Mean step P&L (Normalized Change): 0.0000
# Sharpe (per-hour proxy): 1.92
# Max drawdown (Normalized): -1.35%
